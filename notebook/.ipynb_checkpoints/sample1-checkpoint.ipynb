# %%
# add python path
import sys
sys.path.append('/home/yard/workspace/yard')

# %%
# load tocsv module
from yard.utils.tocsv import dataframe_from_db

# %%
# get data from database

code = 'KORBIT'
start_date = '2014-08-10'
end_date = '2014-08-11'
column = 'dt, bid_price1, ask_price1'

df = dataframe_from_db(code, column, start_date, end_date)
# Out:
# /home/yard/.virtualenvs/yard/local/lib/python2.7/site-packages/pandas/io/sql.py:1196: FutureWarning: frame_query is deprecated, use read_sql
#   warnings.warn("frame_query is deprecated, use read_sql", FutureWarning)

# %%
# plot it
# %matplotlib inline
df.cumsum(0).plot()
